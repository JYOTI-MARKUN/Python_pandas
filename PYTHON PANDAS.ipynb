# %% [markdown]
# ### Loding Data Using Pandas

# %%
import pandas as pd

# %%
df=pd.read_csv("pokemon_data.csv")

# %%
df.head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
# reading a excel file 
#df_xls=pd.read_excel("pokemo_data.xlsx")
#df_xls
# reading a tab seprated file or text file
#df2=pd.read_csv("pokemon_data.txt",delimiter="\t")  # delimiter can be anything
#df2

# %%
# to print/read the headers in pandas
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# to read each columns 
df["Name"].head(5)
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
 # or
df["Name"][5:9]
# Out:
# 5                   Charmeleon
# 6                    Charizard
# 7    CharizardMega Charizard X
# 8    CharizardMega Charizard Y
# Name: Name, dtype: object

# %%
# read column 
df.Name
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
# read multiple columns 
df[["Name","HP","Attack"]][6:9]
# Out:
#                         Name  HP  Attack
# 6                  Charizard  78      84
# 7  CharizardMega Charizard X  78     130
# 8  CharizardMega Charizard Y  78     104

# %%
# read each row
df.iloc[1]
# read multiple rows usng iloc(integer location )function
df.iloc[1:4]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
# Read a specific LOaction (R,c)
df.iloc[3,2]
# Out:
# 'Grass'

# %%
# to iterate each row in dataset
for index,row in df.iterrows():
    print(index,row["Name"])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# ...

# %%
# loc in pandas to loacte a non numerica data 
df.loc[df["Type 1"]=="Grass"]
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# #### Sorting/Describing Data

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values("Name",ascending=False)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# sorting with multiple columns
df.sort_values(["Type 1","HP"])
# Out:
#        #       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292   Shedinja    Bug   Ghost    1      90       45       30       30
# 230  213    Shuckle    Bug    Rock   20      10      230       10      230
# 462  415     Combee    Bug  Flying   30      30       42       30       42
# 603  543   Venipede    Bug  Poison   30      45       59       30       39
# 314  290    Nincada    Bug  Ground   31      45       90       30       30
# ..   ...        ...    ...     ...  ...     ...      ...      ...      ...
# 142  131     Lapras  Water     Ice  130      85       80       85       95
# 145  134   Vaporeon  Water     NaN  130      65       60      110       95
# 350  320    Wailmer  Water     NaN  130      70       35       70       35
# 655  594  Alomomola  Water     NaN  165      75       80       40       45
# 351  321    Wailord  Water     NaN  170      90       45       90       45
#
#      Speed  Generation  Legendary
# ...

# %%
# sorting with multiple condition with one ascending and one descending
df.sort_values(["Name","HP"],ascending=[1,0])
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# #### Making Changes to Data

# %%
# creating a new column in dataframe
df["Total"]=df["HP"]+df["Attack"]+df["Defense"]+df["Sp. Atk"]+df["Sp. Def"]+df["Speed"]
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
# droping a column in pandas
df=df.drop(columns=["Total"])
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# creating a column second method
df["Toatl"]=df.iloc[:,4:10].sum(axis=1) # axis is define to get total along column

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Toatl
# 0         65       65     45           1      False    318
# ...

# %%
# changing the position of a perticular column in dataframe
cols=list(df.columns) # making list of columns of dataframe
df=df[cols[0:4]+cols[-1]+cols[4:12]]  # as we have only one column in cols[-1] so its a kinds of string to make it list
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 # changing the position of a perticular column in dataframe
#       2 cols=list(df.columns) # making list of columns of dataframe
# ----> 3 df=df[cols[0:4]+cols[-1]+cols[4:12]]
#
# TypeError: can only concatenate list (not "str") to list

# %%
df=df[cols[0:4] + [cols[-1]] + cols[4:12]]
df

# %% [markdown]
# #### Saving a change back to CSV / Excel /text

# %%
# Saving a csv file
df.to_csv("modified_csv",index=False)

# %%
# Saving a Excel file
df.to_excel("modifies2.xlsx",index=False)

# %%
# Saving  a text file
df.to_csv("save.txt",sep="\t",index=False)

# %% [markdown]
# #### Filtering  Data

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Toatl
# 0         65       65     45           1      False    318
# ...

# %%
df["Type 2"]
# Out:
# 0      Poison
# 1      Poison
# 2      Poison
# 3      Poison
# 4         NaN
#         ...
# 795     Fairy
# 796     Fairy
# 797     Ghost
# 798      Dark
# 799     Water
# Name: Type 2, Length: 800, dtype: object

# %%
df.loc[(df["Type 1"]=="Grass") & (df["Type 2"]=="Poison")]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 75    69             Bellsprout  Grass  Poison   50      75       35       70
# 76    70             Weepinbell  Grass  Poison   65      90       50       85
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 344  315                Roselia  Grass  Poison   50      60       45      100
# ...

# %%
df.loc[(df["Type 1"]=="Grass") | (df["Type 2"]=="Poison")]
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 16    13                 Weedle    Bug    Poison   40      35       30
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Toatl
# ...

# %%
df2=df.loc[(df["Type 1"]=="Grass") & (df["Type 2"]=="Poison") & (df["HP"]>=75)]
df2
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 652  591              Amoonguss  Grass  Poison  114      85       70       85
#
#      Sp. Def  Speed  Generation  Legendary  Toatl
# 2        100     80           1      False    525
# 3        120     80           1      False    625
# 50        90     50           1      False    490
# 77        70     70           1      False    490
# 652       80     30           5      False    464

# %%
df.loc[((df["Type 1"]=="Grass") |(df["Type 1"]=="Fire")) & (df["Type 2"]=="Ground")]
# Out:
#        #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 352  322                  Numel   Fire  Ground  60      60       40       65
# 353  323               Camerupt   Fire  Ground  70     100       70      105
# 354  323  CameruptMega Camerupt   Fire  Ground  70     120      100      145
# 434  389               Torterra  Grass  Ground  95     109      105       75
#
#      Sp. Def  Speed  Generation  Legendary  Toatl
# 352       45     35           3      False    305
# 353       75     40           3      False    460
# 354      105     20           3      False    560
# 434       85     56           4      False    525

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Toatl
# 0         65       65     45           1      False    318
# ...

# %%
df2
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 652  591              Amoonguss  Grass  Poison  114      85       70       85
#
#      Sp. Def  Speed  Generation  Legendary  Toatl
# 2        100     80           1      False    525
# 3        120     80           1      False    625
# 50        90     50           1      False    490
# 77        70     70           1      False    490
# 652       80     30           5      False    464

# %%
# reindex a dataframe
df2=df2.reset_index()

# %%
df2
# Out:
#    index    #                   Name Type 1  Type 2   HP  Attack  Defense  \
# 0      2    3               Venusaur  Grass  Poison   80      82       83
# 1      3    3  VenusaurMega Venusaur  Grass  Poison   80     100      123
# 2     50   45              Vileplume  Grass  Poison   75      80       85
# 3     77   71             Victreebel  Grass  Poison   80     105       65
# 4    652  591              Amoonguss  Grass  Poison  114      85       70
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Toatl
# 0      100      100     80           1      False    525
# 1      122      120     80           1      False    625
# 2      110       90     50           1      False    490
# 3      100       70     70           1      False    490
# 4       85       80     30           5      False    464

# %%
df.loc[~df["Name"].str.contains("Mega")]
# Out:
#        #                 Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1            Bulbasaur    Grass  Poison   45      49       49       65
# 1      2              Ivysaur    Grass  Poison   60      62       63       80
# 2      3             Venusaur    Grass  Poison   80      82       83      100
# 4      4           Charmander     Fire     NaN   39      52       43       60
# 5      5           Charmeleon     Fire     NaN   58      64       58       80
# ..   ...                  ...      ...     ...  ...     ...      ...      ...
# 794  718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 795  719              Diancie     Rock   Fairy   50     100      150      100
# 797  720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 799  721            Volcanion     Fire   Water   80     110      120      130
#
# ...

# %% [markdown]
# ##### Filering Data Using Regular Expression

# %%
import re
df.loc[df["Type 1"].str.contains('Fire| Grass',regex=True)]
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %%
df.loc[df["Type 1"].str.contains('fire|grass',flags=re.I,regex=True)]  # flags=re.I means ignore case
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 4      4             Charmander   Fire     NaN   39      52       43       60
# ..   ...                    ...    ...     ...  ...     ...      ...      ...
# 735  667                 Litleo   Fire  Normal   62      50       58       73
# 736  668                 Pyroar   Fire  Normal   86      68       72      109
# 740  672                 Skiddo  Grass     NaN   66      65       48       62
# 741  673                 Gogoat  Grass     NaN  123     100       62       97
# 799  721              Volcanion   Fire   Water   80     110      120      130
#
# ...

# %%
# starts with pi
df.loc[df["Name"].str.contains("^pi[a-z]*",flags=re.I,regex=True)]
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 20    16               Pidgey    Normal    Flying   40      45       40
# 21    17            Pidgeotto    Normal    Flying   63      60       55
# 22    18              Pidgeot    Normal    Flying   83      80       75
# 23    18  PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 30    25              Pikachu  Electric       NaN   35      55       40
# 136  127               Pinsir       Bug       NaN   65     125      100
# 137  127    PinsirMega Pinsir       Bug    Flying   65     155      120
# 186  172                Pichu  Electric       NaN   20      40       15
# 219  204               Pineco       Bug       NaN   50      65       90
# 239  221            Piloswine       Ice    Ground  100     100       80
# 438  393               Piplup     Water       NaN   53      51       53
# 558  499              Pignite      Fire  Fighting   90      93       55
# ...

# %% [markdown]
# #### Conditional Changes

# %%
df.loc[df["Type 1"]=="Fire","Type 1"]="Flame"
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander    Flame     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion    Flame   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Toatl
# 0         65       65     45           1      False    318
# ...

# %%
df.loc[df["Type 1"]=="Flame","Type 1"]="Fire"
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Toatl
# 0         65       65     45           1      False    318
# ...

# %%
# changing row based on another row
df.loc[df["Type 1"]=="Fire","Legendary"]=True
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Toatl Legemdary
# ...

# %%
df=pd.read_csv("pokemon_data.csv")
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
cols=list(cols)
df["Total"]=df.iloc[:,4:10].sum(axis=1)
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
# modifying multiple columns
df.loc[df["Total"]>500,["Legendary","Generation"]]=["Very Fast","Advanced"]
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed Generation  Legendary  Total
# 0         65       65     45          1      False    318
# ...

# %% [markdown]
# #### Aggregate Statistics (Groupby)

# %%
df=pd.read_excel("modifies2.xlsx")

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Toatl  Legemdary
# ...

# %%
df.groupby(["Type 1"]).mean()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_12496\4224353277.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["Type 1"]).mean()
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Bug       334.492754  56.884058   70.971014   70.724638  53.869565  64.797101
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Electric  363.500000  59.795455   69.090909   66.295455  90.022727  73.704545
# Fairy     449.529412  74.117647   61.529412   65.705882  78.529412  84.705882
# Fighting  363.851852  69.851852   96.777778   65.925926  53.111111  64.703704
# Fire      327.403846  69.903846   84.769231   67.769231  88.980769  72.211538
# ...

# %%
df.groupby(["Type 1"]).mean().sort_values("Defense",ascending=False)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_12496\4079628779.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["Type 1"]).mean().sort_values("Defense",ascending=False)
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Steel     442.851852  65.222222   92.703704  126.370370  67.518519  80.629630
# Rock      392.727273  65.363636   92.863636  100.795455  63.340909  75.477273
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Ground    356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# Ghost     486.500000  64.437500   73.781250   81.187500  79.343750  76.468750
# Water     303.089286  72.062500   74.151786   72.946429  74.812500  70.517857
# ...

# %%
df.groupby(["Type 1"]).mean().sort_values("Attack",ascending=False)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_12496\299722232.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["Type 1"]).mean().sort_values("Attack",ascending=False)
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Fighting  363.851852  69.851852   96.777778   65.925926  53.111111  64.703704
# Ground    356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# Rock      392.727273  65.363636   92.863636  100.795455  63.340909  75.477273
# Steel     442.851852  65.222222   92.703704  126.370370  67.518519  80.629630
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# ...

# %%
df.groupby(["Type 1"]).sum()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_12496\2189449682.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["Type 1"]).sum()
#               #    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Type 1
# Bug       23080  3925    4897     4880     3717     4471   4256         222
# Dark      14302  2071    2740     2177     2314     2155   2361         125
# Dragon    15180  2666    3588     2764     3099     2843   2657         124
# Electric  15994  2631    3040     2917     3961     3243   3718         144
# Fairy      7642  1260    1046     1117     1335     1440    826          70
# Fighting   9824  1886    2613     1780     1434     1747   1784          91
# Fire      17025  3635    4408     3524     4627     3755   3871         167
# ...

# %%
df.groupby(["Type 1"]).count()
# Out:
#             #  Name  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug        69    69      52   69      69       69       69       69     69
# Dark       31    31      21   31      31       31       31       31     31
# Dragon     32    32      21   32      32       32       32       32     32
# Electric   44    44      17   44      44       44       44       44     44
# Fairy      17    17       2   17      17       17       17       17     17
# Fighting   27    27       7   27      27       27       27       27     27
# Fire       52    52      24   52      52       52       52       52     52
# Flying      4     4       2    4       4        4        4        4      4
# Ghost      32    32      22   32      32       32       32       32     32
# Grass      70    70      37   70      70       70       70       70     70
# Ground     32    32      19   32      32       32       32       32     32
# ...

# %%
df["count"]=1

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Toatl  Legemdary  count
# ...

# %%
df.groupby(["Type 1"]).count()["count"]
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %%
df.groupby(["Type 1","Type 2"]).count()["count"]
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %% [markdown]
# ### Now on this database we have some questions

# %% [markdown]
#  ###### Q. How many Pokemons exist with an Attack value greater than 150?

# %%
(df["Attack"]>150).value_counts()
# Out:
# False    782
# True      18
# Name: Attack, dtype: int64

# %% [markdown]
# Here we have  True value 18 (according to our given condition we get a bollean column of True and False Value and by valye_counts operation we can count the value of both but here we need only True Value)

# %% [markdown]
# ##### Q. Select all pokemons with a Speed of 10 or less
#
# Use filtering to select those "slow" Pokemons with a Speed value of 10 or less. Store your results in the variable slow_pokemons_df.

# %%
slow_pokemons_df = df.loc[df["Speed"]<=10]

# %%
slow_pokemons_df.head()
# Out:
#        #       Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 230  213    Shuckle     Bug   Rock   20      10      230       10      230
# 359  328   Trapinch  Ground    NaN   45     100       45       45       45
# 486  438     Bonsly    Rock    NaN   50      80       95       10       45
# 495  446   Munchlax  Normal    NaN  135      85       40       40       85
# 658  597  Ferroseed   Grass  Steel   44      50       91       24       86
#
#      Speed  Generation  Legendary
# 230      5           2      False
# 359     10           3      False
# 486     10           4      False
# 495      5           4      False
# 658     10           5      False

# %% [markdown]
# ##### Q. How many Pokemons have a Sp. Def value of 25 or less?
#
# The Sp. Def value indicates the defense power of a pokemon against Special abilities. How many pokemons have a value of 25 or less?

# %%
(df["Sp. Def"]<=25).value_counts()
# Out:
# False    782
# True      18
# Name: Sp. Def, dtype: int64

# %%
The answer is 18 and this has the same explanation as the question one

# %% [markdown]
# ##### Q. Select all the Legendary pokemons
#
# Select only pokemons that are Legendary and store the result in the variable legendary_df

# %%
legendary_df =df.loc[df["Legendary"]==True]
legendary_df
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 156  144             Articuno       Ice    Flying   90      85      100
# 157  145               Zapdos  Electric    Flying   90      90       85
# 158  146              Moltres      Fire    Flying   90     100       90
# 162  150               Mewtwo   Psychic       NaN  106     110       90
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting  106     190      100
# ..   ...                  ...       ...       ...  ...     ...      ...
# 795  719              Diancie      Rock     Fairy   50     100      150
# 796  719  DiancieMega Diancie      Rock     Fairy   50     160      110
# 797  720  HoopaHoopa Confined   Psychic     Ghost   80     110       60
# 798  720   HoopaHoopa Unbound   Psychic      Dark   80     160       60
# 799  721            Volcanion      Fire     Water   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ##### Q. How many Fire-Flying Pokemons are there?
#
# How many pokemons are of Type 1Fire and Type 2Flying?

# %%
df2=(df.loc[(df["Type 1"]=="Fire") & (df["Type 2"]=="Flying")])
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 6 to 731
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           6 non-null      int64
#  1   Name        6 non-null      object
#  2   Type 1      6 non-null      object
#  3   Type 2      6 non-null      object
#  4   HP          6 non-null      int64
#  5   Attack      6 non-null      int64
#  6   Defense     6 non-null      int64
#  7   Sp. Atk     6 non-null      int64
#  8   Sp. Def     6 non-null      int64
#  9   Speed       6 non-null      int64
#  10  Generation  6 non-null      int64
#  11  Legendary   6 non-null      bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 582.0+ bytes

# %% [markdown]
# ##### Q. How many 'Poison' pokemons are across both types?
#
# How many pokemons exist that are of type Poison in either Type 1 or Type 2?

# %%
df2=(df.loc[(df["Type 1"]=="Poison") | (df["Type 2"]=="Poison")])
df2.info()
df2
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 62 entries, 0 to 761
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           62 non-null     int64
#  1   Name        62 non-null     object
#  2   Type 1      62 non-null     object
#  3   Type 2      47 non-null     object
#  4   HP          62 non-null     int64
#  5   Attack      62 non-null     int64
#  6   Defense     62 non-null     int64
#  7   Sp. Atk     62 non-null     int64
#  8   Sp. Def     62 non-null     int64
#  9   Speed       62 non-null     int64
#  10  Generation  62 non-null     int64
#  11  Legendary   62 non-null     bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 5.9+ KB
#        #                   Name  Type 1  Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur   Grass  Poison   45      49       49
# 1      2                Ivysaur   Grass  Poison   60      62       63
# ...

# %% [markdown]
# ##### Q. What pokemon of Type 1 Ice has the strongest defense?
#
# Please enter the name of the Ice Type Pokémon with the highest defense below.

# %%
df.loc[(df["Type 1"]=="Ice"),"Defense" ].max()
# Out:
# 184

# %%
df.loc[(df["Type 1"]=="Ice") & (df["Defense"]==df.loc[(df["Type 1"]=="Ice"),"Defense" ].max())].head()
# Out:
#        #     Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 789  713  Avalugg    Ice    NaN  95     117      184       44       46     28
#
#      Generation  Legendary
# 789           6      False

# %% [markdown]
# so the answer is Avalugg

# %% [markdown]
# ##### Q. What's the most common type of Legendary Pokemons?
#
# What's the most common Type 1 for legendary pokemons? Enter it below.

# %%
df.loc[df["Legendary"],"Type 1"].value_counts()
# Out:
# Psychic     14
# Dragon      12
# Fire         5
# Electric     4
# Water        4
# Rock         4
# Steel        4
# Ground       4
# Grass        3
# Ice          2
# Normal       2
# Ghost        2
# Dark         2
# Flying       2
# Fairy        1
# Name: Type 1, dtype: int64

# %% [markdown]
# so the answer od this question is Psychic

# %% [markdown]
# ##### Q. What's the most powerful pokemon from the first 3 generations, of type water?
#
# Find the most powerful Pokemon (by Total) from the first 3 generations that is of Type 1 'Water'. Enter its name below.

# %%
#first of all for this we need to add a column of total
df["Total"]=df["Attack"]+df["Defense"]+df["Sp. Def"]+df["Sp. Atk"]+df["Speed"]

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    273
# 1       80     60           1      False    345
# 2      100     80           1      False    445
# 3      120     80           1      False    545
# 4       50     65           1      False    270

# %%
df.loc[
    (df["Type 1"]=="Water") & 
    df["Generation"].isin ([1,2,3])
].sort_values(by="Total",ascending=False).head()
# Out:
#        #                     Name Type 1  Type 2   HP  Attack  Defense  \
# 422  382      KyogrePrimal Kyogre  Water     NaN  100     150       90
# 421  382                   Kyogre  Water     NaN  100     100       90
# 12     9  BlastoiseMega Blastoise  Water     NaN   79     103      120
# 141  130    GyaradosMega Gyarados  Water    Dark   95     155      109
# 283  260    SwampertMega Swampert  Water  Ground  100     150      110
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 422      180      160     90           3       True    670
# 421      150      140     90           3       True    570
# 12       135      115     78           1      False    551
# 141       70      130     81           1      False    545
# 283       95      110     70           3      False    535

# %% [markdown]
# so the answer is KyogrePrime kyogre

# %% [markdown]
# ##### Q.What's the most powerful Dragon from the last two generations?
#
# Find the most powerful pokemon (by Total) that is of type Dragon (either Type 1 or Type 2) and from the last two generations. Enter its name below. If there are multiple, enter the name of the Dragon with higher index value.

# %%
df["Generation"].value_counts()
# Out:
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: Generation, dtype: int64

# %%
df.loc[
    ((df["Type 1"]=="Dragon")|  (df["Type 1"]=="Dragon")) & 
    df["Generation"].isin ([5,6])
].sort_values(by="Total",ascending=False).head()
# Out:
#        #                Name  Type 1    Type 2   HP  Attack  Defense  Sp. Atk  \
# 706  643            Reshiram  Dragon      Fire  100     120      100      150
# 707  644              Zekrom  Dragon  Electric  100     150      120      120
# 711  646  KyuremBlack Kyurem  Dragon       Ice  125     170      100      120
# 712  646  KyuremWhite Kyurem  Dragon       Ice  125     120       90      170
# 710  646              Kyurem  Dragon       Ice  125     130       90      130
#
#      Sp. Def  Speed  Generation  Legendary  Total
# 706      120     90           5       True    580
# 707      100     90           5       True    580
# 711       90     95           5       True    575
# 712      100     95           5       True    575
# 710       90     95           5       True    535

# %% [markdown]
# We have two power Dragon type pokemon by total so we will choose the one who has highest index number i.e. ZeKrom

# %% [markdown]
# ##### Q. Select most powerful Fire-type pokemons
#
# Select all pokemons that have an Attack value above 100 and Type 1 equals to Fire (ignore Type 2 in this activity). Store the result in powerful_fire_df.

# %%
powerful_fire_df=df.loc[(df["Type 1"]=="Fire") & (df["Attack"]>100)]
powerful_fire_df.head()
# Out:
#        #                       Name Type 1  Type 2   HP  Attack  Defense  \
# 7      6  CharizardMega Charizard X   Fire  Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire  Flying   78     104       78
# 64    59                   Arcanine   Fire     NaN   90     110       80
# 147  136                    Flareon   Fire     NaN   65     130       60
# 263  244                      Entei   Fire     NaN  115     115       85
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 7        130       85    100           1      False    556
# 8        159      115    100           1      False    556
# 64       100       80     95           1      False    465
# 147       95      110     65           1      False    460
# 263       90       75    100           2       True    465

# %% [markdown]
# ##### Q. Select all Water-type, Flying-type pokemons
#
# Select those pokemons that are of Type 1Water and Type 2Flying. Store the selection in the variable water_flying_df.

# %%
water_flying_df=df.loc[(df["Type 1"]=="Water") & (df["Type 2"]=="Flying")]
water_flying_df.head()
# Out:
#        #      Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 140  130  Gyarados  Water  Flying  95     125       79       60      100
# 244  226   Mantine  Water  Flying  65      40       70       80      140
# 301  278   Wingull  Water  Flying  40      30       30       55       30
# 302  279  Pelipper  Water  Flying  60      50      100       85       70
# 508  458   Mantyke  Water  Flying  45      20       50       60      120
#
#      Speed  Generation  Legendary  Total
# 140     81           1      False    445
# 244     70           2      False    400
# 301     85           3      False    230
# 302     65           3      False    370
# 508     50           4      False    300

# %% [markdown]
# ##### Q. Select specific columns of Legendary pokemons of type Fire
#
# Perform a selection in your Dataframe of all the Legendary pokemons that are of Type 1Fire. But select only the columns Name, Attack and Generation. Store the results in a variable legendary_fire_df.

# %%
legendary_fire_df=df.loc[(df["Type 1"]=="Fire") &(df["Legendary"]) ,["Name","Attack","Generation"]]
legendary_fire_df.head()
# Out:
#           Name  Attack  Generation
# 158    Moltres     100           1
# 263      Entei     115           2
# 270      Ho-oh     130           2
# 542    Heatran      90           4
# 799  Volcanion     110           6

# %% [markdown]
# ##### Q. Select Slow and Fast pokemons
#
# Take a look at the distribution of Pokemon's speed in the histogram included in the notebook. The red lines separate the slowest (bottom 5%) and fastest (top 5%) pokemons.
#
# Select those pokemons that are either very slow (with Speed below the bottom 5%) or very fast (Speed above top 95%).
#
# Store your results in the variable slow_fast_df

# %%
# This is the distribution of speed of the pokemons. The red lines indicate those bottom 5% and top 5% pokemons by speed:

ax = df['Speed'].plot(kind='hist', figsize=(10, 5), bins=100)
ax.axvline(df['Speed'].quantile(.05), color='red')
ax.axvline(df['Speed'].quantile(.95), color='red')

# %%
bottom_5=df["Speed"].quantile(.05)
top_95=df["Speed"].quantile(.95)
(bottom_5,top_95)
# Out:
# (25.0, 115.0)

# %%
slow_fast_df=df.loc[(df["Speed"]>bottom_5) | (df["Speed"]>top_95) ]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    273
# 1       80     60           1      False    345
# 2      100     80           1      False    445
# 3      120     80           1      False    545
# 4       50     65           1      False    270
